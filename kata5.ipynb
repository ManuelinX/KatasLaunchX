# %%
from math import ceil

distanciaTierra = 149597870
distanciaJupiter = 778547200

distancia = abs(distanciaTierra-distanciaJupiter)
print(distancia)
distanciaMillas = distancia*0.621
print(ceil(distanciaMillas))
# Out:
# 628949330
# 390577534

# %% [markdown]
# # Ejercicio 2

# %%
planet1 = input("Escribe la primera distancia: ")
planet2 = input("Agrega la segunda distancia: ")
planet1 =  int(planet1)
planet2 = int(planet2)

distancia = abs(planet2-planet1)

print(f"La distancia en kilometros es {distancia}")
print(f'La distancia en millas es {distancia*.621}')
# Out:
# La distancia en kilometros es 5
# La distancia en millas es 3.105
