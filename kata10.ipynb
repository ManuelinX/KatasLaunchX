# %% [markdown]
# # Ejercicio 0

# %%
open("/path/to/mars.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\LunchX\practica\Astronauta.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/LunchX/practica/Astronauta.ipynb#ch0000008?line=0'>1</a> open("/path/to/mars.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'

# %% [markdown]
# # Ejercicio 1

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError as err:
        print("got a problem trying to read the file:", err)
    except IsADirectoryError:
        print("Found config.txt but it is a directory, couldn't read it")
    except PermissionError:
        print("No tienes los permisos para abrir el archivo")
    except (BlockingIOError, TimeoutError):
        print("Filesystem under heavy load, can't complete reading configuration file")


if __name__ == '__main__':
    main()

# %% [markdown]
# # Ejercicio 2

# %%
def main():
    try:
        open('config.txt')
    except OSError as error:
        if error.errno == 2:
            print("Couldn't find the config.txt file!")
        elif error.errno == 13:
            print("Found config.txt but couldn't read it")

if __name__ == '__main__':
    main()

# %% [markdown]
# # Ejercicio 3 Astronautas

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts*11
    total_usaje = daily_usage * days_left
    total_water_left = water_left - total_usaje

    return f"Total water left after {days_left} days is: {total_water_left} liters"


water_left(5, 100, 2)
# Out:
# 'Total water left after 2 days is: -10 liters'

# %%
Traceback (most recent call last):
  File "<stdin>", line 5, in water_left
TypeError: unsupported operand type(s) for /: 'str' and 'int'

During handling of the preceding exception, another exception occurred:

Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
  File "<stdin>", line 9, in water_left
TypeError: All arguments must be of type int, but received: '3'
# Out:
#   Input In [2]
#     Traceback (most recent call last):
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
