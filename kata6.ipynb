# %%
planets = ['Mercurio','Venus','Tierra','Marte','Jupiter','Urano','Neptuno']
print(planets)

planets.append('Pluton')
print(planets[-1])
# Out:
# ['Mercurio', 'Venus', 'Tierra', 'Marte', 'Jupiter', 'Urano', 'Neptuno']
# Pluton

# %% [markdown]
# # Ejercicio 2

# %%
# Lista de planetas
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']

pista = input('Digite un planeta en ingles y en minusculas: ')

for i in range(len(planets)):
    if pista.lower() == planets[i].lower():
        print(f"El planeta {planets[i]} esta en la lista")
        break
# Out:
# El planeta Mars esta en la lista
