# %%
new_planet = ''
planets = []

while new_planet.lower() != 'done':
    if new_planet:
        planets.append(new_planet)
    new_planet = input("Escribe el nombre de un planeta o done para salir: ")

# %% [markdown]
# # Ejercicio 2

# %%
for planet in planets:
    print(planet)
# Out:
# mercurio
# done
